# %%
import dask.dataframe as dd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
installments_payments= dd.read_csv("./data/installments_payments.csv")
a = installments_payments.shape
print("installments_payments shape :({},{})".format( a[0].compute(),a[1]))
# Out:
# installments_payments shape :(13605401,8)

# %%
installments_payments.compute().dtypes.value_counts()
# Out:
# float64    5
# int64      3
# dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(installments_payments.isna().compute(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(installments_payments.compute().corr(),annot=True,cmap='coolwarm')
