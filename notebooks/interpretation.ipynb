# %% [markdown]
# # Interpretation

# %% [markdown]
# - Bureau :
#     * shape :  1716428 lignes , 17 colonnes
#     * type de variable :  3 qualitatives et 14 quantitatives
#     * valeurs manquantes : 12.8% (DAYS_CREDIT_ENDDATE , DAYS_ENDDATE_FACT , AMT_CREDIT_SUM_DEBT, AMT_CREDIT_SUM_LIMIT, AMT_ANNUITY, AMT_CREDIT_MAX_OVERDUE)
#
#     * colonnes :
#         * SK_ID_CURR : n'est pas unique ==>  tableau néccesite une aggregation pour la jointure
#         * SK_ID_BUREAU : unique ==>  parfait pour la jointure
#         * CREDIT_ACTIVE : détection des outliers ("Sold" , "Bad debt")
#         * CREDIT_CURRENCY : colonne inutile car elle base sur une seule valeurs ("currency 1")
#         * DAYS_CREDIT : distribution anormale
#         * CREDIT_DAY_OVERDUE : 	99.8% des valeurs sont des zeros ==> colonne inutile
#         * DAYS_CREDIT_ENDDATE :  Présence des valeurs aberrantes
#         * DAYS_ENDDATE_FACT : suit une loi normale repliée
#         * CNT_CREDIT_PROLONG : 99.5% des valeurs sont des zeros ==> colonne inutile
#         * AMT_CREDIT_SUM : distribution anormale
#         * AMT_CREDIT_SUM_DEBT : 59.2% des valeurs sont des zeros ,  distribution anormale
#         * AMT_CREDIT_SUM_LIMIT : distribution anormale
#         * AMT_CREDIT_SUM_OVERDUE : 99.8% des valeurs sont nulle
#         * CREDIT_TYPE : détection des outliers seulement ("Consumer credit" , "Credit card")
#         * DAYS_CREDIT_UPDATE : suit une loi normale repliée
#         * AMT_ANNUITY : 71.5% valeurs manquantes
#
#     * Relations entre les variables :
#         * DAYS_ENDDATE_FACT / DAYS_CREDIT fortement corrélées : 0.88
#         * DAYS_ENDDATE_FACT / DAYS_CREDIT_UPDATE corrélées : 0.75
#
# - Bureau_balance :
#     * shape :  27299925 lignes , 3 colonnes
#         * type de variable :  1 qualitatives et 2 quantitatives
#         * valeurs manquantes : 0%
#
#         * colonnes :
#             * SK_ID_BUREAU : n'est pas unique ==>  tableau néccesite une aggregation pour la jointure
#             * MONTHS_BALANCE :
#             * STATUS : detection des outliers sauf (C,0,X)
#
#
#         * Relations entre les variables :
#             * pas de relations
#
# - POS_CASH_balance :
#     * shape :  10001358 lignes , 8 colonnes
#         * type de variable :  1 qualitatives et 7 quantitatives
#         * valeurs manquantes : 0,1%
#
#         * colonnes :
#             * SK_ID_PREV : n'est pas unique ==>  tableau néccesite une aggregation pour la jointure
#             * SK_ID_CURR : n'est pas unique ==>  tableau néccesite une aggregation pour la jointure
#             * MONTHS_BALANCE :
#             * CNT_INSTALMENT : distribution anormale comporte des valeurs abberante
#             * CNT_INSTALMENT_FUTURE : n'est pas unique ==>  tableau néccesite une aggregation pour la jointure
#             * NAME_CONTRACT_STATUS : detection des outliers pratiquement tous les variables sont : "active"
#             * SK_DPD : 	97.0% des zeros
#             * SK_DPD_DEF : 98.9% des zeros
#
#         * Relations entre les variables :
#             * CNT_INSTALMENT et CNT_INSTALMENT_FUTURE sont corrolées : 0.87
#
# - installments_payments :
#     * shape :  13605401 lignes , 8 colonnes
#         * type de variable :   8 quantitatives
#         * valeurs manquantes : 0,1%
#
#         * colonnes :
#             * SK_ID_PREV : n'est pas unique ==>  tableau néccesite une aggregation pour la jointure
#             * SK_ID_CURR : n'est pas unique ==>  tableau néccesite une aggregation pour la jointure
#             <!-- * NUM_INSTALMENT_VERSION :
#             * NUM_INSTALMENT_NUMBER :
#             * DAYS_INSTALMENT :
#             * DAYS_ENTRY_PAYMENT :
#             * AMT_INSTALMENT :
#             * AMT_PAYMENT :  -->
#
#         * Relations entre les variables :
#             * AMT_INSTALMENT et AMT_PAYMENT sont corrolées : 0.94
#
# - credit_card_balance :
#     * shape :  3840312 lignes , 23 colonnes
#         * type de variable :   1 qualitatives et 22 quantitatives
#         * valeurs manquantes : 6.4%
#
#         * colonnes :
#             * SK_ID_PREV : n'est pas unique ==>  tableau néccesite une aggregation pour la jointure
#             * SK_ID_CURR : n'est pas unique ==>  tableau néccesite une aggregation pour la jointure
#             * MONTHS_BALANCE :
#             * AMT_BALANCE :
#             * AMT_CREDIT_LIMIT_ACTUAL :
#             * AMT_DRAWINGS_ATM_CURRENT : 69.4% des zeros
#             * AMT_DRAWINGS_CURRENT :   	83.9% des zeros
#             * AMT_DRAWINGS_OTHER_CURRENT : 	80.2% des zeros
#             * AMT_DRAWINGS_POS_CURRENT : 	73.6% des zeros
#             * AMT_INST_MIN_REGULARITY :
#             * AMT_PAYMENT_CURRENT :
#             * AMT_PAYMENT_TOTAL_CURRENT : 56.6% des zeros
#             * AMT_RECEIVABLE_PRINCIPAL : 59.8% des zeros
#             * AMT_RECIVABLE :
#             * AMT_TOTAL_RECEIVABLE :
#             * CNT_DRAWINGS_ATM_CURRENT : 69.4% des zeros
#             * CNT_DRAWINGS_CURRENT :  84.1% des zeros
#             * CNT_DRAWINGS_OTHER_CURRENT : 	80.1% des zeros
#             * CNT_DRAWINGS_POS_CURRENT : 73.6% des zeros
#             * CNT_INSTALMENT_MATURE_CUM :
#             * NAME_CONTRACT_STATUS : detection des outliers pratiquement tous les variables sont : "active"  (colonne existe deja dans pos_cash_balance)
#             * SK_DPD : 	96.0% des zeros (colonne existe deja dans pos_cash_balance)
#             * SK_DPD_DEF : 	97.7% des zeros (colonne existe deja dans pos_cash_balance)
#
#         * Relations entre les variables :
#             * CNT_DRAWINGS_POS_CURRENT et CNT_DRAWINGS_CURRENT sont corrélées : 0.95
#             * AMT_PAYMENT_CURRENT et AMT_PAYMENT_TOTAL_CURRENT sont corrélées  : 0.99 (peut etre meme colonne)
#             * AMT_RECEIVABLE_PRINCIPAL et AMT_INST_MIN_REGULARITY : 0.9
#             * AMT_INST_MIN_REGULARITY et AMT_RECIVABLE : 0.9
#             * AMT_INST_MIN_REGULARITY et AMT_TOTAL_RECEIVABLE : 0.9
#             * AMT_INST_MIN_REGULARITY et AMT_RECIVABLE : 0.9
#             * AMT_INST_MIN_REGULARITY et AMT_BALANCE : 0.9
#             * AMT_RECEIVABLE_PRINCIPAL et AMT_BALANCE :  1 (peut etre meme colonne)
#             * AMT_RECEIVABLE_PRINCIPAL et AMT_RECIVABLE :  1 (peut etre meme colonne)
#             * AMT_RECEIVABLE_PRINCIPAL et AMT_TOTAL_RECEIVABLE :  1 (peut etre meme colonne)
#             * AMT_BALANCE et AMT_TOTAL_RECEIVABLE :  1 (peut etre meme colonne)
#             * AMT_BALANCE et AMT_RECIVABLE :  1 (peut etre meme colonne)
#             * AMT_RECIVABLE et AMT_TOTAL_RECEIVABLE :  1 (peut etre meme colonne)
#
# - previous_application :
#     * shape :  1670214 lignes , 37 colonnes
#         * type de variable :   18 qualitatives et 19 quantitatives
#         * valeurs manquantes : 17.5%
#
#         * colonnes :
#             * SK_ID_PREV :  unique ==>  parfait pour la jointure
#             * SK_ID_CURR : n'est pas unique ==>  tableau néccesite une aggregation pour la jointure
#             * NAME_CONTRACT_TYPE : XNA : outliers
#             * AMT_ANNUITY : distribution demi normale , 22.3% missing value
#             * AMT_APPLICATION : distribution demi normale
#             * AMT_CREDIT : 1 missing value
#             * AMT_DOWN_PAYMENT : 53.6% missing value
#             * AMT_GOODS_PRICE :  	23.1% missing value
#             * WEEKDAY_APPR_PROCESS_START : SUNDAY et SATURDAY valeurs qui sont pas logiques
#             * HOUR_APPR_PROCESS_START :  distribution normale
#             * FLAG_LAST_APPL_PER_CONTRACT : tous le valeurs sont pratiquements true ==> colonne inutile
#             * NFLAG_LAST_APPL_IN_DAY : tous le valeurs sont pratiquements 1 ==> colonne inutile
#             * NFLAG_MICRO_CASH
#             * RATE_DOWN_PAYMENT : 53.6% valeurs manquantes presence des valeurs abberantes
#             * RATE_INTEREST_PRIMARY : 	99.6% missing values ==> colonne inutile
#             * RATE_INTEREST_PRIVILEGED : 	99.6% missing values ==> colonne inutile
#             * NAME_CASH_LOAN_PURPOSE : XAP et XNA sont sont majoritaires
#             * NAME_CONTRACT_STATUS :  " Unused offer " ==> outliers
#             * DAYS_DECISION
#             * NAME_PAYMENT_TYPE : detection des outliers sauf (Cash through the bank,XNA)
#             * CODE_REJECT_REASON : colonne inutile car la majorite des valeurs sont XAP
#             * NAME_TYPE_SUITE : 	49.1% missing value
#             * NAME_CLIENT_TYPE :   " XNA  " ==> outliers
#             * NAME_GOODS_CATEGORY
#             * NAME_PORTFOLIO : "cars" ==> outliers
#             * NAME_PRODUCT_TYPE
#             * CHANNEL_TYPE
#             * SELLERPLACE_AREA
#             * NAME_SELLER_INDUSTRY
#             * CNT_PAYMENT : 	22.3% missing, presence des valeurs abberantes
#             * NAME_YIELD_GROUP
#             * PRODUCT_COMBINATION : missing 0.1%
#             * DAYS_FIRST_DRAWING : 	40.3% missing
#             * DAYS_FIRST_DUE :  40.3% missing
#             * DAYS_LAST_DUE_1ST_VERSION : 	40.3% missing
#             * DAYS_LAST_DUE : 	40.3% missing
#             * DAYS_TERMINATION : 	40.3% missing
#             * NFLAG_INSURED_ON_APPROVAL : 	40.3% missing
#
#
# - application_train :
#     * shape :  307511 lignes , 122 colonnes
#         * type de variable :   18 qualitatives et 19 quantitatives
#         * valeurs manquantes : 17.5%
#
#         * colonnes :
#             * TARGET
#             * NAME_CONTRACT_TYPE
#             * CODE_GENDER
#             * FLAG_OWN_CAR
#             * FLAG_OWN_REALTY
#             * CNT_CHILDREN
#             * AMT_INCOME_TOTAL
#             * AMT_CREDIT
#             * AMT_ANNUITY
#             * AMT_GOODS_PRICE
#             * NAME_TYPE_SUITE
#             * NAME_INCOME_TYPE
#             * NAME_EDUCATION_TYPE
#             * NAME_FAMILY_STATUS
#             * NAME_HOUSING_TYPE
#             * REGION_POPULATION_RELATIVE
#             * DAYS_BIRTH
#             * DAYS_EMPLOYED
#             * DAYS_REGISTRATION
#             * DAYS_ID_PUBLISH
#             * OWN_CAR_AGE
#             * FLAG_MOBIL
#             * FLAG_EMP_PHONE
#             * FLAG_WORK_PHONE
#             * FLAG_CONT_MOBILE
#             * FLAG_PHONE
#             * FLAG_EMAIL
#             * OCCUPATION_TYPE
#             * CNT_FAM_MEMBERS
#             * REGION_RATING_CLIENT
#             * REGION_RATING_CLIENT_W_CITY
#             * WEEKDAY_APPR_PROCESS_START
#             * HOUR_APPR_PROCESS_START
#             * REG_REGION_NOT_LIVE_REGION
#             * REG_REGION_NOT_WORK_REGION
#             * LIVE_REGION_NOT_WORK_REGION
#             * REG_CITY_NOT_LIVE_CITY
#             * REG_CITY_NOT_WORK_CITY
#             * LIVE_CITY_NOT_WORK_CITY
#             * ORGANIZATION_TYPE
#             * EXT_SOURCE_1
#             * EXT_SOURCE_2
#             * EXT_SOURCE_3
#             * APARTMENTS_AVG
#             * BASEMENTAREA_AVG
#             * YEARS_BEGINEXPLUATATION_AVG
#             * YEARS_BUILD_AVG
#             * COMMONAREA_AVG
#             * ELEVATORS_AVG
#             * ENTRANCES_AVG
#             * FLOORSMAX_AVG
#             * FLOORSMIN_AVG
#             * LANDAREA_AVG
#             * LIVINGAPARTMENTS_AVG
#             * LIVINGAREA_AVG
#             * NONLIVINGAPARTMENTS_AVG
#             * NONLIVINGAREA_AVG
#             * APARTMENTS_MODE
#             * BASEMENTAREA_MODE
#             * YEARS_BEGINEXPLUATATION_MODE
#             * YEARS_BUILD_MODE
#             * COMMONAREA_MODE
#             * ELEVATORS_MODE
#             * ENTRANCES_MODE
#             * FLOORSMAX_MODE
#             * FLOORSMIN_MODE
#             * LANDAREA_MODE
#             * LIVINGAPARTMENTS_MODE
#             * LIVINGAREA_MODE
#             * NONLIVINGAPARTMENTS_MODE
#             * NONLIVINGAREA_MODE
#             * APARTMENTS_MEDI
#             * BASEMENTAREA_MEDI
#             * YEARS_BEGINEXPLUATATION_MEDI
#             * YEARS_BUILD_MEDI
#             * COMMONAREA_MEDI
#             * ELEVATORS_MEDI
#             * ENTRANCES_MEDI
#             * FLOORSMAX_MEDI
#             * FLOORSMIN_MEDI
#             * LANDAREA_MEDI
#             * LIVINGAPARTMENTS_MEDI
#             * LIVINGAREA_MEDI
#             * NONLIVINGAPARTMENTS_MEDI
#             * NONLIVINGAREA_MEDI
#             * FONDKAPREMONT_MODE
#             * HOUSETYPE_MODE
#             * TOTALAREA_MODE
#             * WALLSMATERIAL_MODE
#             * EMERGENCYSTATE_MODE
#             * OBS_30_CNT_SOCIAL_CIRCLE
#             * DEF_30_CNT_SOCIAL_CIRCLE
#             * OBS_60_CNT_SOCIAL_CIRCLE
#             * DEF_60_CNT_SOCIAL_CIRCLE
#             * DAYS_LAST_PHONE_CHANGE
#             * FLAG_DOCUMENT_2
#             * FLAG_DOCUMENT_3
#             * FLAG_DOCUMENT_4
#             * FLAG_DOCUMENT_5
#             * FLAG_DOCUMENT_6
#             * FLAG_DOCUMENT_7
#             * FLAG_DOCUMENT_8
#             * FLAG_DOCUMENT_9
#             * FLAG_DOCUMENT_10
#             * FLAG_DOCUMENT_11
#             * FLAG_DOCUMENT_12
#             * FLAG_DOCUMENT_13
#             * FLAG_DOCUMENT_14
#             * FLAG_DOCUMENT_15
#             * FLAG_DOCUMENT_16
#             * FLAG_DOCUMENT_17
#             * FLAG_DOCUMENT_18
#             * FLAG_DOCUMENT_19
#             * FLAG_DOCUMENT_20
#             * FLAG_DOCUMENT_21
#             * AMT_REQ_CREDIT_BUREAU_HOUR
#             * AMT_REQ_CREDIT_BUREAU_DAY
#             * AMT_REQ_CREDIT_BUREAU_WEEK
#             * AMT_REQ_CREDIT_BUREAU_MON
#             * AMT_REQ_CREDIT_BUREAU_QRT
#             * AMT_REQ_CREDIT_BUREAU_YEAR
